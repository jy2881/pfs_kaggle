# %%
import pandas as pd

# %%
train = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\sales_train_v2.csv")
test = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\test.csv",index_col="ID")
sub = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\sample_submission.csv",index_col="ID")
shop = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\shops.csv")
item_categories = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\item_categories.csv")
items = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\items.csv")

# %%
train = train.sort_values(by=["date_block_num","shop_id","item_id"])

# %%
train_m = pd.DataFrame(train.head(1))
for i in train.index[1:1000]:
    if train.loc[i,"shop_id"] == train_m.iloc[-1]["shop_id"] and train.loc[i,"item_id"] == train_m.iloc[-1]["item_id"] and train.loc[i,"date_block_num"] == train_m.iloc[-1]["date_block_num"]:
        train_m.iloc[-1]["item_cnt_day"] += train.loc[i,"item_cnt_day"]
    else:
        train_m = train_m.append(train.loc[i,:])
train_m
# Out:
# D:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#              date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 40085  03.01.2013               0        0       32       221.0           2.0
# 40089  03.01.2013               0        0       33       347.0           1.0
# 40092  31.01.2013               0        0       35       247.0           1.0
# 40095  31.01.2013               0        0       43       221.0           1.0
# 40093  13.01.2013               0        0       51       130.0           1.0
# 40097  10.01.2013               0        0       61       195.0           1.0
# ...
