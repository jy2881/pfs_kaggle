# %%
import pandas as pd

# %%
train = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\sales_train_v2.csv")
test = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\test.csv",index_col="ID")
sub = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\sample_submission.csv",index_col="ID")
shop = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\shops.csv")
item_categories = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\item_categories.csv")
items = pd.read_csv(r"E:\12. githubR\pfs_kaggle\pfs_kaggle\data\items.csv")
items
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# 5      ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6               ***УДАР ПО ВОРОТАМ (UNI)               D        6
# 7             ***УДАР ПО ВОРОТАМ-2 (UNI)               D        7
# 8               ***ЧАЙ С МУССОЛИНИ                     D        8
# 9          ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D        9
# 10             *ЗА ГРАНЬЮ СМЕРТИ                       D       10
# 11             *ЛИНИЯ СМЕРТИ                           D       11
# 12                       *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12
# ...

# %%
train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# ...

# %%
type(train.tail(1)["shop_id"][1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-50a23137721c> in <module>()
# ----> 1 type(train.tail(1)["shop_id"][1])
#
# D:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# D:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
# ...

# %%
train = train.sort_values(by=["date_block_num","shop_id","item_id"])
train_m = train.head(1)
for i in train.index[1:]:
    if train.loc[i]["shop_id"] == train_m.iloc[-1]["shop_id"]:
        print(i)
        train_m.tail(1)["item_cnt_day"] += train.loc[i]["item_cnt_day"]
    else:
        train_m.contact(train.loc[i],ignore_index=False)
        print("haha")
train_m
